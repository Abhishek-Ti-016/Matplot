# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
nop1 = [5,10,12,3,15,30,45]
nop2 = [4,10,16,14,18,20,40]
nop3 = [18,14,19,53,74,60,50]

plt.stackplot(days,nop1,nop2,nop3,labels = ["Week 1","Week 2","Week 3"] )
plt.legend()
plt.show()

# %%
import pandas as pd

data = pd.read_csv("Employee.csv")
df = pd.DataFrame(data)
group = pd.prop
plt.stackplot(df["Age"],df["Bonus %"])
plt.show()
print(df)
# Out:
#     Employee ID          Full Name              Job Title   Department  \
# 0        E02002             Kai Le      Controls Engineer  Engineering
# 1        E02003       Robert Patel                Analyst        Sales
# 2        E02004         Cameron Lo  Network Administrator           IT
# 3        E02005    Harper Castillo   IT Systems Architect           IT
# 4        E02006   Harper Dominguez               Director  Engineering
# ..          ...                ...                    ...          ...
# 105      E02109      Lillian Desai         Field Engineer  Engineering
# 106      E02110    Avery Gutierrez         Vice President    Marketing
# 107      E02111  Caroline Sandoval                Analyst        Sales
# 108      E02112         Hailey Lim               Director    Marketing
# 109      E02113        Roman Liang            Sr. Analyst        Sales
#
#      Gender Ethnicity  Age  Annual Salary  Bonus %        Country
# ...
